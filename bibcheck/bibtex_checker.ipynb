# %%
from helpers import check_bib, compare_bibs, format_journal_name, find_duplicates, get_vals, load_bibliography, duplicate_inds, printv, last_names_from_str
import numpy as np

# %%
#format_journal_name(format_journal_name('Essays in Honor of {William} {K.} {Estes}')) == format_journal_name('Essays in Honor of {William} {K.} {Estes}')

# %%
errors1, corrected_bib1 = check_bib('../cdl.bib', autofix=True, outfile='cleaned.bib')
# Out:
# loading ../cdl.bib...done
# Checking for duplicated keys and entries...
# No keys with multiple entries were found.
# 0it [00:00, ?it/s]
# No entries with duplicated authors/titles were found.
#
#
# running check: ID...
# 5744it [00:00, 112143.82it/s]
# no IDs to fix!
# 5744it [00:00, 121224.73it/s]
# 5744it [00:00, 117074.61it/s]
# running check: ID...
# 2 errors detected:
# FranEtal06: 	ID "FranEtal06" should be "FranEtal06a"
# FranEtal06c: 	ID "FranEtal06c" should be "FranEtal06b"
#
#
# No ambiguous page numbers were found.
#
#
# running check: pages...
# no pagess to fix!
# 5744it [00:00, 118194.04it/s]
# running check: journal...
# 73 errors detected:
# Trei98: 	journal "Philosophical Transactions of the Royal Society of London Series B: Biological Sciences" should be "Philosophical Transactions of the Royal Society of London Series {B}: Biological Sciences"
# Bart04: 	journal "European Physical Journal {B}" should be "{European} Physical Journal {B}"
# WarrEtal10: 	journal "European Journal of Cardiovascular Prevention and Rehabilitation" should be "{European} Journal of Cardiovascular Prevention and Rehabilitation"
# SteeEtal97: 	journal "European Journal of Oral Sciences" should be "{European} Journal of Oral Sciences"
# DamEtal16: 	journal "Sensors and Actuators B: Chemical" should be "Sensors and Actuators {B}: Chemical"
# TurGEtal17: 	journal "Sensors and Actuators B: Chemical" should be "Sensors and Actuators {B}: Chemical"
# LiuEtal16: 	journal "Sensors and Actuators B: Chemical" should be "Sensors and Actuators {B}: Chemical"
# CotmBerc07: 	journal "Alzheimer's and Dementia" should be "{Alzheimer's} and Dementia"
# EggeEtal07: 	journal "Research and Practice in Alzheimer's Disease" should be "Research and Practice in {Alzheimer's} Disease"
# SegaEtal12: 	journal "Journal of Alzheimer's Disease" should be "Journal of {Alzheimer's} Disease"
# VaynEtal04: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# LachEtal00b: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# Fris05: 	journal "Philosophical Transactions of the Royal Society of London Series B: Biological Sciences" should be "Philosophical Transactions of the Royal Society of London Series {B}: Biological Sciences"
# KlinEtal96: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# NybeTulv96: 	journal "European Journal of Cognitive Psychology" should be "{European} Journal of Cognitive Psychology"
# LittEtal11: 	journal "Philosophical Transactions of the Royal Society of London Series B: Biological Sciences" should be "Philosophical Transactions of the Royal Society of London Series {B}: Biological Sciences"
# Sing98: 	journal "Philosophical Transactions of the Royal Society of London Series B: Biological Sciences" should be "Philosophical Transactions of the Royal Society of London Series {B}: Biological Sciences"
# FillEtal08: 	journal "Alzheimer's and Dementia" should be "{Alzheimer's} and Dementia"
# PanzEtal99: 	journal "Proceedings of the Royal Society of London Series B: Biological Sciences" should be "Proceedings of the Royal Society of London Series {B}: Biological Sciences"
# HalpEtal07: 	journal "Parkinsonism and Related Disorders" should be "{Parkinsonism} and Related Disorders"
# TrenEtal07: 	journal "Journal of Alzheimer's Disease" should be "Journal of {Alzheimer's} Disease"
# IariEtal08: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# ShibYuki03: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# SausEtal07: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# CentEtal01: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# MollEtal02: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# NandEtal09: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# BaunEtal01: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# KlimEtal03: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# CharEtal04: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# Morr01: 	journal "Philosophical Transactions of the Royal Society of London Series B: Biological Sciences" should be "Philosophical Transactions of the Royal Society of London Series {B}: Biological Sciences"
# BogaEtal07: 	journal "Philosophical Transactions of the Royal Society of London Series B: Biological Sciences" should be "Philosophical Transactions of the Royal Society of London Series {B}: Biological Sciences"
# Holm45: 	journal "Proceedings of the Royal Society of London Series B: Biological Sciences" should be "Proceedings of the Royal Society of London Series {B}: Biological Sciences"
# DuzeEtal04: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# JensTesc02: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# FrieEckh00: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# PentEtal98: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# MishEtal97: 	journal "Philosophical Transactions of the Royal Society of London Series B: Biological Sciences" should be "Philosophical Transactions of the Royal Society of London Series {B}: Biological Sciences"
# SpeaOKee90: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# Jaco14: 	journal "Philosophical Transactions of the Royal Society of London Series B: Biological Sciences" should be "Philosophical Transactions of the Royal Society of London Series {B}: Biological Sciences"
# Colt83: 	journal "Philosophical Transactions of the Royal Society of London Series B: Biological Sciences" should be "Philosophical Transactions of the Royal Society of London Series {B}: Biological Sciences"
# SaulEtal09: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# BurgEtal01b: 	journal "Philosophical Transactions of the Royal Society of London Series B: Biological Sciences" should be "Philosophical Transactions of the Royal Society of London Series {B}: Biological Sciences"
# WardEtal12: 	journal "Alzheimer's and Dementia" should be "{Alzheimer's} and Dementia"
# WallMill03: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# TulvHaym95: 	journal "European Journal of Cognitive Psychology" should be "{European} Journal of Cognitive Psychology"
# Crai83: 	journal "Philosophical Transactions of the Royal Society of London Series B: Biological Sciences" should be "Philosophical Transactions of the Royal Society of London Series {B}: Biological Sciences"
# Bert97: 	journal "Philosophical Transactions of the Royal Society of London Series B: Biological Sciences" should be "Philosophical Transactions of the Royal Society of London Series {B}: Biological Sciences"
# MagnEtal90: 	journal "European Journal of Cognitive Psychology" should be "{European} Journal of Cognitive Psychology"
# WeniIrle06: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# ClarEtal11: 	journal "Proceedings of the Royal Society of London Series B: Biological Sciences" should be "Proceedings of the Royal Society of London Series {B}: Biological Sciences"
# AnniHopc02: 	journal "Journal of Physics A: Mathematical and General" should be "Journal of Physics {A}: Mathematical and General"
# GregGard94: 	journal "European Journal of Cognitive Psychology" should be "{European} Journal of Cognitive Psychology"
# GrubEtal06: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# IariEtal07: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# BenaEtal93: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# FellEtal03: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# Kura81: 	journal "Physica A: Statistical and Theoretical Physics" should be "Physica {A}: Statistical and Theoretical Physics"
# PhamEtal05: 	journal "Proceedings of the Institution of Mechanical Engineers, Part C: Journal of Mechanical Engineering Science" should be "Proceedings of the Institution of Mechanical Engineers, Part {C}: Journal of Mechanical Engineering Science"
# TounEtal99: 	journal "Alzheimer's Disease and Associated Disorders" should be "{Alzheimer's} Disease and Associated Disorders"
# HougBing04: 	journal "Journal of Comparative Physiology A: Sensory, Neural, and Behavioral Physiology" should be "Journal of Comparative Physiology {A}: Sensory, Neural, and Behavioral Physiology"
# BellEtal03: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# BartEtal11a: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# ZrenEtal11: 	journal "Proceedings of the Royal Society of London Series B: Biological Sciences" should be "Proceedings of the Royal Society of London Series {B}: Biological Sciences"
# GaynEtal08: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# CzurEtal99: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# PennEtal93: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# ClauEtal04: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# Fred04: 	journal "Philosophical Transactions of the Royal Society of London Series B: Biological Sciences" should be "Philosophical Transactions of the Royal Society of London Series {B}: Biological Sciences"
# LlinEtal98: 	journal "Philosophical Transactions of the Royal Society of London Series B: Biological Sciences" should be "Philosophical Transactions of the Royal Society of London Series {B}: Biological Sciences"
# WillEtal05b: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# VanCEtal08: 	journal "European Journal of Neuroscience" should be "{European} Journal of Neuroscience"
# UnswBrew10: 	journal "European Journal of Cognitive Psychology" should be "{European} Journal of Cognitive Psychology"
# 5744it [00:00, 121463.09it/s]
# running check: booktitle...
# 14 errors detected:
# BjorBjor92: 	booktitle "Essays in Honor of {William} {K.} {Estes}" should be "Essays in Honor of {William} {K}. {Estes}"
# RescWagn72: 	booktitle "Classical Conditioning Ii: Current Research and Theory" should be "Classical Conditioning {II}: Current Research and Theory"
# GunzLyon07: 	booktitle "Spatial Cognition V: Reasoning, Action, Interaction" should be "Spatial Cognition {V}: Reasoning, Action, Interaction"
# NilsGard91: 	booktitle "Relating Theory and Data: Essays on Human Memory in Honor of {Bennet} {B.} {Murdock}" should be "Relating Theory and Data: Essays on Human Memory in Honor of {Bennet} {B}. {Murdock}"
# Este91: 	booktitle "Relating Theory and Data: Essays on Human Memory in Honor of {Bennet} {B.} {Murdock}" should be "Relating Theory and Data: Essays on Human Memory in Honor of {Bennet} {B}. {Murdock}"
# GoebLewa91: 	booktitle "Relating Theory and Data: Essays on Human Memory in Honor of {Bennet} {B.} {Murdock}" should be "Relating Theory and Data: Essays on Human Memory in Honor of {Bennet} {B}. {Murdock}"
# Murd92b: 	booktitle "Essays in Honor of {William} {K.} {Estes}" should be "Essays in Honor of {William} {K}. {Estes}"
# HealPark01: 	booktitle "The Nature of Remembering: Essays in Honor of {Robert} {G.} {Crowder}" should be "The Nature of Remembering: Essays in Honor of {Robert} {G}. {Crowder}"
# RoedEtal01a: 	booktitle "The Nature of Remembering: Essays in Honor of {Robert} {G.} {Crowder}" should be "The Nature of Remembering: Essays in Honor of {Robert} {G}. {Crowder}"
# AshbMadd98: 	booktitle "Choice, Decision, and Measurement: Essays in Honor of {R.} {Duncan} {Luce}" should be "Choice, Decision, and Measurement: Essays in Honor of {R}. {Duncan} {Luce}"
# Post72: 	booktitle "Human Memory: Festschrift in Honor of {Benton} {J.} {Underwood}" should be "Human Memory: Festschrift in Honor of {Benton} {J}. {Underwood}"
# ShifRaai92: 	booktitle "Essays in Honor of {William} {K.} {Estes}" should be "Essays in Honor of {William} {K}. {Estes}"
# SteyEtal04: 	booktitle "Cognitive Psychology and Its Applications: Festschrift in Honor of Lyle Bourne, {Walter} Kintsch, and {Thomas} Landauer" should be "Cognitive Psychology and Its Applications: Festschrift in Honor of Lyle Bourne, {Walter} {Kintsch}, and {Thomas} {Landauer}"
# Mand91: 	booktitle "Relating Theory and Data: Essays on Human Memory in Honor of {Bennet} {B.} {Murdock}" should be "Relating Theory and Data: Essays on Human Memory in Honor of {Bennet} {B}. {Murdock}"
# 5744it [00:00, 114231.92it/s]
# running check: title...
# 2409 errors detected:
# DevlEtal18: 	title "BERT: pre-training of deep bidirectional transformers for language understanding" should be "{BERT}: pre-training of deep bidirectional transformers for language understanding"
# Gros88: 	title "Nonlinear neural networks: Principles, mechanisms, and architectures" should be "Nonlinear neural networks: principles, mechanisms, and architectures"
# Fris00: 	title "The labile brain. I. Neuronal transients and nonlinear coupling" should be "The labile brain. {I}. Neuronal transients and nonlinear coupling"
# JackWool18: 	title "Adaptive coding in the human brain: Distinct object features are encoded by overlapping voxels in frontoparietal cortex" should be "Adaptive coding in the human brain: distinct object features are encoded by overlapping voxels in frontoparietal cortex"
# ReddEtal18: 	title "Genetic and neuroanatomical support for functional brain network dynamics in epilepsy Authors Genetic and neuroanatomical support for functional brain network dynamics in epilepsy" should be "Genetic and neuroanatomical support for functional brain network dynamics in epilepsy authors genetic and neuroanatomical support for functional brain network dynamics in epilepsy"
# WuEtal11: 	title "Gamma-oscillations modulated by picture naming and word reading: Intracranial recording in epileptic patients" should be "Gamma-oscillations modulated by picture naming and word reading: intracranial recording in epileptic patients"
# SherEtal16: 	title "Neural mechanisms of transient neocortical beta rhythms: Converging evidence from humans, computational modeling, monkeys, and mice" should be "Neural mechanisms of transient neocortical beta rhythms: converging evidence from humans, computational modeling, monkeys, and mice"
# JurkEtal06: 	title "Post-movement beta rebound is generated in motor cortex: Evidence from neuromagnetic recordings" should be "Post-movement beta rebound is generated in motor cortex: evidence from neuromagnetic recordings"
# EngeEtal10: 	title "{Dynamic Coordination in the Brain: From Neurons to Mind}" should be "Dynamic coordination in the brain: from neurons to mind"
# BichEtal05: 	title "Parallel and serial neural mechanisms for visual search in macaque area V4" should be "Parallel and serial neural mechanisms for visual search in macaque area {V4}"
# RegeEtal18: 	title "Propagation of Information Along the Cortical Hierarchy as a Function of Attention While Reading and Listening to Stories" should be "Propagation of information along the cortical hierarchy as a function of attention while reading and listening to stories"
# HillMunt84: 	title "Selective attention to color and location: An analysis with event-related brain potentials" should be "Selective attention to color and location: an analysis with event-related brain potentials"
# McAdMaun00: 	title "Attention to both space and feature modulates neuronal responses in macaque area V4" should be "Attention to both space and feature modulates neuronal responses in macaque area {V4}"
# PeirEtal19: 	title "PsychoPy2: experiments in behavior made easy" should be "{PsychoPy2}: experiments in behavior made easy"
# MoorZirn17: 	title "Neural Mechanisms of Selective Visual Attention" should be "Neural mechanisms of selective visual attention"
# UncaEtal11: 	title "Dissociable Effects of Top-Down and Bottom-Up Attentionduring Episodic Encoding" should be "Dissociable effects of top-down and bottom-up attentionduring episodic encoding"
# MeyeEtal12: 	title "Evidence for social working memory from a parametric functional MRI study" should be "Evidence for social working memory from a parametric functional {MRI} study"
# ZikeEtal17: 	title "{OCD candidate gene SLC1A1/EAAT3 impacts basal ganglia-mediated activity and stereotypic behavior}" should be "{OCD} candidate gene {SLC1A1/EAAT3} impacts basal ganglia-mediated activity and stereotypic behavior"
# HoneEtal12b: 	title "Not lost in translation: Neural responses shared across languages" should be "Not lost in translation: neural responses shared across languages"
# KellEtal02: 	title "Finding the self? An event-related fMRI study" should be "Finding the self? An event-related {fMRI} study"
# McClEtal86: 	title "{Parallel distributed processing}" should be "Parallel distributed processing"
# DiazEtal19: 	title "Dopamine Neurotransmission in the Ventral Tegmental Area Promotes Active Forgetting of Cocaine-Associated Memory" should be "Dopamine neurotransmission in the ventral tegmental area promotes active forgetting of cocaine-associated memory"
# HumpEtal07: 	title "Time course of semantic processes during sentence comprehension: an fMRI study" should be "Time course of semantic processes during sentence comprehension: an {fMRI} study"
# XiaoEtal05: 	title "Differential activity in left inferior frontal gyrus for pseudowords and real words: An event-related fMRI study on auditory lexical decision" should be "Differential activity in left inferior frontal gyrus for pseudowords and real words: an event-related {fMRI} study on auditory lexical decision"
# IschEtal04: 	title "Reading in a regular orthography: an FMRI study investigating the role of visual familiarity" should be "Reading in a regular orthography: an {fMRI} study investigating the role of visual familiarity"
# RissEtal03: 	title "An event-related fMRI investigation of implicit semantic priming" should be "An event-related {fMRI} investigation of implicit semantic priming"
# HensEtal02: 	title "Detecting latency differences in event-related BOLD responses: application to words versus nonwords and initial versus repeated face presentations" should be "Detecting latency differences in event-related {BOLD} responses: application to words versus nonwords and initial versus repeated face presentations"
# BaumEtal02: 	title "Event-related fMRI reveals cortical sites involved in contextual sentence integration" should be "Event-related {fMRI} reveals cortical sites involved in contextual sentence integration"
# McKiEtal06: 	title "Interrupting the ``stream of consciousness'': an fMRI investigation" should be "Interrupting the ``stream of consciousness'': an {fMRI} investigation"
# BindEtal99: 	title "Conceptual processing during the conscious resting state: a functional MRI study" should be "Conceptual processing during the conscious resting state: a functional {MRI} study"
# WimbEtal09: 	title "Retrieval from episodic memory: Neural mechanisms of interference resolution" should be "Retrieval from episodic memory: neural mechanisms of interference resolution"
# BargThei85: 	title "Individual construct accessibility, person memory, and the recall-judgment link: The case of information overload" should be "Individual construct accessibility, person memory, and the recall-judgment link: the case of information overload"
# OddoEtal10: 	title "Specific role of medial prefrontal cortex in retrieving recent autobiographical memories: an fMRI study of young female subjects" should be "Specific role of medial prefrontal cortex in retrieving recent autobiographical memories: an {fMRI} study of young female subjects"
# NikiLuo02: 	title "An fMRI study on the time-limited role of the medial temporal lobe in long-term topographical autobiographic memory" should be "An {fMRI} study on the time-limited role of the medial temporal lobe in long-term topographical autobiographic memory"
# BonnEtal12: 	title "Detecting representations of recent and remote autobiographical memories in vmPFC and hippocampus" should be "Detecting representations of recent and remote autobiographical memories in {vmPFC} and hippocampus"
# TakaEtal07: 	title "Memory trace stabilization leads to large-scale changes in the retrieval network: a functional MRI study on associative memory" should be "Memory trace stabilization leads to large-scale changes in the retrieval network: a functional {MRI} study on associative memory"
# ZwaaEtal95: 	title "The construction of situation models in narrative comprehension: An event-indexing model" should be "The construction of situation models in narrative comprehension: an event-indexing model"
# Wilc45: 	title "individual comparisons by ranking methods" should be "Individual comparisons by ranking methods"
# BechEtal19: 	title "Dimensionality reduction for visualizing single-cell data using UMAP" should be "Dimensionality reduction for visualizing single-cell data using {UMAP}"
# Fish25: 	title "Statistical Methods for Research Workers" should be "Statistical methods for research workers"
# GaoEtal15: 	title "Pycortex: an interactive surface visualizer for fMRI" should be "{Pycortex}: an interactive surface visualizer for {fMRI}"
# HaluEtal13: 	title "{Multiplex PageRank}" should be "Multiplex {PageRank}"
# RicoSzei06: 	title "Towards a unifying approach to diversity measures: Bridging the gap between the {Shannon} entropy and {Rao's} quadratic index" should be "Towards a unifying approach to diversity measures: bridging the gap between the {Shannon} entropy and {Rao's} quadratic index"
# SoloEtal18: 	title "MTL functional connectivity predicts stimulation-induced theta power" should be "{MTL} functional connectivity predicts stimulation-induced theta power"
# MoriEtal08: 	title "Stereotaxic white matter atlas based on diffusion tensor imaging in an ICBM template" should be "Stereotaxic white matter atlas based on diffusion tensor imaging in an icbm template"
# JahaEtal13: 	title "Multi-site genetic analysis of diffusion images and voxelwise heritability analysis: A pilot project of the ENIGMA-DTI working group" should be "Multi-site genetic analysis of diffusion images and voxelwise heritability analysis: A pilot project of the enigma-dti working group"
# MuelEtal18: 	title "{WordCloud 1.5.0: a little word cloud generator in Python}" should be "{WordCloud} 1.5.0: a little word cloud generator in {Python}"
# ZadbEtal17: 	title "How We Transmit Memories to Other Brains: Constructing Shared Neural Representations Via Communication" should be "How we transmit memories to other brains: constructing shared neural representations via communication"
# GilbMarl17: 	title "Neurobiology of Schemas and Schema-Mediated Memory" should be "Neurobiology of schemas and schema-mediated memory"
# McInEtal18: 	title "{UMAP}: Uniform Manifold Approximation and Projection for Dimension Reduction" should be "{UMAP}: uniform manifold approximation and projection for dimension reduction"
# ClewDava17: 	title "The Ebb and Flow of Experience Determines the Temporal Structure of Memory" should be "The ebb and flow of experience determines the temporal structure of memory"
# RadvZack17: 	title "Event Boundaries in Memory and Cognition" should be "Event boundaries in memory and cognition"
# McKeBuzs16: 	title "Micro-, Meso- and Macro-Dynamics of the Brain, Research and Perspectives in Neurosciences" should be "Micro-, meso- and macro-dynamics of the brain, research and perspectives in neurosciences"
# CapoEtal17: 	title "Brain Imaging Analysis Kit" should be "Brain imaging analysis kit"
# SalaEtal11: 	title "{Walking before study enhances free recall but not judgement-of-learning magnitude}" should be "Walking before study enhances free recall but not judgement-of-learning magnitude"
# BercEtal05: 	title "{Exercise primes a molecular memory for brain-derived neurotrophic factor protein induction in the rat hippocampus}" should be "Exercise primes a molecular memory for brain-derived neurotrophic factor protein induction in the rat hippocampus"
# SchrBaue97: 	title "{State-Dependent Learning in Older and Younger Adults}" should be "State-dependent learning in older and younger adults"
# SuzuEtal11: 	title "{Astrocyte-Neuron Lactate Transport Is Required for Long-Term Memory Formation}" should be "Astrocyte-neuron lactate transport is required for long-term memory formation"
# GregEtal04: 	title "{Effects of long duration exercise on cognitive function, blood glucose, and counterregulatory hormones in male cyclists}" should be "Effects of long duration exercise on cognitive function, blood glucose, and counterregulatory hormones in male cyclists"
# McGa89: 	title "{Involvement of Hormonal of Memory Storage}" should be "Involvement of hormonal of memory storage"
# HeisEtal15: 	title "{Age differences in the association of physical activity, sociocognitive engagement, and TV viewing on face memory}" should be "Age differences in the association of physical activity, sociocognitive engagement, and {TV} viewing on face memory"
# Park05: 	title "{Effect of arousal and retention delay on memory: a meta-analysis}" should be "Effect of arousal and retention delay on memory: a meta-analysis"
# StonDawe93: 	title "{Acute Exercise Facilitates Semantically Cued Memory in Nursing Home Residents}" should be "Acute exercise facilitates semantically cued memory in nursing home residents"
# MangEtal14: 	title "{A single bout of high-intensity aerobic exercise facilitates response to paired associative stimulation and promotes sequence-specific implicit motor learning}" should be "A single bout of high-intensity aerobic exercise facilitates response to paired associative stimulation and promotes sequence-specific implicit motor learning"
# StatEtal15: 	title "{A single bout of moderate aerobic exercise improves motor skill acquisition}" should be "A single bout of moderate aerobic exercise improves motor skill acquisition"
# SnowEtal16: 	title "{The effect of an acute bout of moderate-intensity aerobic exercise on motor learning of a continuous tracking task}" should be "The effect of an acute bout of moderate-intensity aerobic exercise on motor learning of a continuous tracking task"
# LabbEtni11: 	title "{Effects of Acute Exercise on Long-Term Memory}" should be "Effects of acute exercise on long-term memory"
# PescEtal09: 	title "{Physical activity and mental performance in preadolescents: Effects of acute exercise on free-recall memory}" should be "Physical activity and mental performance in preadolescents: effects of acute exercise on free-recall memory"
# DiazEtal15: 	title "{Fitbit: An accurate and reliable device for wireless physical activity tracking}" should be "Fitbit: an accurate and reliable device for wireless physical activity tracking"
# DontEtal15: 	title "{Measuring steps with the Fitbit activity tracker: an inter-device reliability study}" should be "Measuring steps with the fitbit activity tracker: an inter-device reliability study"
# GajeFalk15: 	title "{Long-term habitual physical activity is associated with lower distractibility in a Stroop interference task in aging: Behavioral and ERP evidence}" should be "Long-term habitual physical activity is associated with lower distractibility in a {Stroop} interference task in aging: behavioral and {ERP} evidence"
# ScudEtal14: 	title "{The association between aerobic fitness and language processing in children: Implications for academic achievement}" should be "The association between aerobic fitness and language processing in children: implications for academic achievement"
# DustEtal90: 	title "{Age and fitness effects on EEG, ERPs, visual sensitivity, and cognition}" should be "Age and fitness effects on {EEG}, {ERPs}, visual sensitivity, and cognition"
# NaveEtal00: 	title "The effects of divided attention on encoding and retrieval processes: The resiliency of retrieval processes" should be "The effects of divided attention on encoding and retrieval processes: the resiliency of retrieval processes"
# BallEtal09a: 	title "{Disposable electrochemiluminescent biosensor for lactate determination in saliva}" should be "Disposable electrochemiluminescent biosensor for lactate determination in saliva"
# ShirEtal00: 	title "{Assessing Estradiol in Biobehavioral Studies Using Saliva and Blood Spots: Simple Radioimmunoassay Protocols, Reliability, and Comparative Validity}" should be "Assessing estradiol in biobehavioral studies using saliva and blood spots: simple radioimmunoassay protocols, reliability, and comparative validity"
# RoigEtal12: 	title "{A Single Bout of Exercise Improves Motor Memory}" should be "A single bout of exercise improves motor memory"
# Dabb90: 	title "{Salivary testosterone measurements: Reliability across hours, days, and weeks}" should be "Salivary testosterone measurements: reliability across hours, days, and weeks"
# DishEtal06: 	title "{Neurobiology of Exercise}" should be "Neurobiology of exercise"
# ChatEtal96: 	title "{Salivary alpha-amylase as a measure of endogenous adrenergic activity}" should be "Salivary alpha-amylase as a measure of endogenous adrenergic activity"
# SeguEtal96: 	title "{A new approach to the assessment of anaerobic metabolism: measurement of lactate in saliva}" should be "A new approach to the assessment of anaerobic metabolism: measurement of lactate in saliva"
# SegaCahi09: 	title "{Endogenous noradrenergic activation and memory for emotional material in men and women}" should be "Endogenous noradrenergic activation and memory for emotional material in men and women"
# WarrEtal10: 	title "{Assessment of physical activity--- a review of methodologies with reference to epidemiological research: a report of the exercise physiology section of the European Association of Cardiovascular Prevention and Rehabilitation}" should be "Assessment of physical activity--- a review of methodologies with reference to epidemiological research: a report of the exercise physiology section of the {European} association of cardiovascular prevention and rehabilitation"
# BuddEtal10: 	title "{Steroid hormones in the saliva of adolescents after different exercise intensities and their influence on working memory in a school setting}" should be "Steroid hormones in the saliva of adolescents after different exercise intensities and their influence on working memory in a school setting"
# MaroEtal12: 	title "{Are the neuroprotective effects of estradiol and physical exercise comparable during ageing in female rats?}" should be "Are the neuroprotective effects of estradiol and physical exercise comparable during ageing in female rats?"
# SaadEtal14b: 	title "{Prior regular exercise prevents synaptic plasticity impairment in sleep deprived female rats}" should be "Prior regular exercise prevents synaptic plasticity impairment in sleep deprived female rats"
# AriEtal04: 	title "{Serum testosterone, growth hormone, and insulin-like growth factor-1 levels, mental reaction time, and maximal aerobic exercise in sedentary and long-term physically trained elderly males}" should be "Serum testosterone, growth hormone, and insulin-like growth factor-1 levels, mental reaction time, and maximal aerobic exercise in sedentary and long-term physically trained elderly males"
# NiemEtal13: 	title "{Influence of acute and chronic physical activity on cognitive performance and saliva testosterone in preadolescent school children}" should be "Influence of acute and chronic physical activity on cognitive performance and saliva testosterone in preadolescent school children"
# PetrEtal15: 	title "{Psychosocial stress increases salivary alpha-Amylase activity independently from plasma noradrenaline levels}" should be "Psychosocial stress increases salivary alpha-amylase activity independently from plasma noradrenaline levels"
# ChoiEtal14: 	title "{Real-time measurement of human salivary cortisol for the assessment of psychological stress using a smartphone}" should be "Real-time measurement of human salivary cortisol for the assessment of psychological stress using a smartphone"
# MoffHamp96: 	title "{Salivary testosterone levels in left- and right-handed adults}" should be "Salivary testosterone levels in left- and right-handed adults"
# MullEtal05: 	title "{Endogenous sex hormone levels and cognitive function in aging men}" should be "Endogenous sex hormone levels and cognitive function in aging men"
# PhilEtal98: 	title "The FERET database and evaluation procedure for face-recognition algorithms" should be "The feret database and evaluation procedure for face-recognition algorithms"
# ShutEtal83: 	title "{The relationship between androgen levels and human spatial abilities}" should be "The relationship between androgen levels and human spatial abilities"
# GattDePa11: 	title "{An update: Salivary hormones and physical exercise}" should be "An update: salivary hormones and physical exercise"
# MoraEtal07: 	title "{Aging, plasticity and environmental enrichment: Structural changes and neurotransmitter dynamics in several areas of the brain}" should be "Aging, plasticity and environmental enrichment: structural changes and neurotransmitter dynamics in several areas of the brain"
# McMoEtal11: 	title "{Acute, intermediate intensity exercise, and speed and accuracy in working memory tasks: A meta-analytical comparison of effects}" should be "Acute, intermediate intensity exercise, and speed and accuracy in working memory tasks: A meta-analytical comparison of effects"
# GilmEtal79: 	title "{Effects of exercise stress on parotid gland secretion}" should be "Effects of exercise stress on parotid gland secretion"
# KivlGran06: 	title "{Salivary alpha-amylase response to competition: Relation to gender, previous experience, and attitudes}" should be "Salivary alpha-amylase response to competition: relation to gender, previous experience, and attitudes"
# CookBeav13: 	title "{Salivary testosterone is related to self-selected training load in elite female athletes}" should be "Salivary testosterone is related to self-selected training load in elite female athletes"
# EdwaCast13: 	title "{Women's intercollegiate athletic competition: Cortisol, testosterone, and the dual-hormone hypothesis as it relates to status among teammates}" should be "Women's intercollegiate athletic competition: cortisol, testosterone, and the dual-hormone hypothesis as it relates to status among teammates"
# BuchEtal13: 	title "{Monitoring fitness, fatigue and running performance during a pre-season training camp in elite football players}" should be "Monitoring fitness, fatigue and running performance during a pre-season training camp in elite football players"
# SteeEtal97: 	title "{Salivary levels of immunoglobulin A in triathletes}" should be "Salivary levels of immunoglobulin A in triathletes"
# EdwaCast15: 	title "{Baseline cortisol moderates testosterone reactivity to women's intercollegiate athletic competition}" should be "Baseline cortisol moderates testosterone reactivity to women's intercollegiate athletic competition"
# LjunEtal97: 	title "{Saliva and marathon running}" should be "Saliva and marathon running"
# CalvEtal97: 	title "{Anaerobic threshold determination with analysis of salivary amylase}" should be "Anaerobic threshold determination with analysis of salivary amylase"
# BishEtal06: 	title "{Salivary IgA responses to prolonged intensive exercise following caffeine ingestion}" should be "Salivary iga responses to prolonged intensive exercise following caffeine ingestion"
# NateEtal06: 	title "{Stress-induced changes in human salivary alpha-amylase activity - Associations with adrenergic activity}" should be "Stress-induced changes in human salivary alpha-amylase activity - associations with adrenergic activity"
# DamEtal16: 	title "{Toward wearable patch for sweat analysis}" should be "Toward wearable patch for sweat analysis"
# TurGEtal17: 	title "{Novel flexible enzyme laminate-based sensor for analysis of lactate in sweat}" should be "Novel flexible enzyme laminate-based sensor for analysis of lactate in sweat"
# LiuEtal16: 	title "{A wearable conductivity sensor for wireless real-time sweat monitoring}" should be "A wearable conductivity sensor for wireless real-time sweat monitoring"
# ShapEtal10: 	title "{Directed evolution of a magnetic resonance imaging contrast agent for noninvasive imaging of dopamine}" should be "Directed evolution of a magnetic resonance imaging contrast agent for noninvasive imaging of dopamine"
# Arch11b: 	title "{Influence of physical exercise on traumatic brain injury deficits: Scaffolding effect}" should be "Influence of physical exercise on traumatic brain injury deficits: scaffolding effect"
# Lojo10: 	title "{The Relationship Between Aerobic Exercise and Cognition: Is Movement Medicinal?}" should be "The relationship between aerobic exercise and cognition: is movement medicinal?"
# TaruEtal13: 	title "{Central artery stiffness, neuropsychological function, and cerebral perfusion in sedentary and endurance-trained middle-aged adults}" should be "Central artery stiffness, neuropsychological function, and cerebral perfusion in sedentary and endurance-trained middle-aged adults"
# ZagaEtal13a: 	title "{Regular treadmill exercise prevents sleep deprivation-induced disruption of synaptic plasticity and associated signaling cascade in the dentate gyrus}" should be "Regular treadmill exercise prevents sleep deprivation-induced disruption of synaptic plasticity and associated signaling cascade in the dentate gyrus"
# ZagaEtal13b: 	title "{Regular exercise prevents sleep deprivation associated impairment of long-term memory and synaptic plasticity in the CA1 area of the hippocampus}" should be "Regular exercise prevents sleep deprivation associated impairment of long-term memory and synaptic plasticity in the {CA1} area of the hippocampus"
# FernEtal13: 	title "{Aerobic exercise attenuates inhibitory avoidance memory deficit induced by paradoxical sleep deprivation in rats}" should be "Aerobic exercise attenuates inhibitory avoidance memory deficit induced by paradoxical sleep deprivation in rats"
# SchmEtal03: 	title "{Memory and attention functions in middle-aged and elderly subjects are unaffected by a low, acute dose of caffeine}" should be "Memory and attention functions in middle-aged and elderly subjects are unaffected by a low, acute dose of caffeine"
# HogeEtal99: 	title "{Caffeine improves cognitive performance after strenuous physical exercise}" should be "Caffeine improves cognitive performance after strenuous physical exercise"
# HogeEtal08: 	title "{Caffeine improves physical and cognitive performance during exhaustive exercise}" should be "Caffeine improves physical and cognitive performance during exhaustive exercise"
# MileHard98: 	title "{State-dependent memory produced by aerobic exercise}" should be "State-dependent memory produced by aerobic exercise"
# HameChid08: 	title "{Physical activity and risk of neurodegenerative disease: a systematic review of prospective evidence}" should be "Physical activity and risk of neurodegenerative disease: a systematic review of prospective evidence"
# SaadEtal14a: 	title "{Prior regular exercise reverses the decreased effects of sleep deprivation on brain-derived neurotrophic factor levels in the hippocampus of ovariectomized female rats}" should be "Prior regular exercise reverses the decreased effects of sleep deprivation on brain-derived neurotrophic factor levels in the hippocampus of ovariectomized female rats"
# SalaEtal15: 	title "{The compensatory effect of regular exercise on long-term memory impairment in sleep deprived female rats}" should be "The compensatory effect of regular exercise on long-term memory impairment in sleep deprived female rats"
# SaadEtal15: 	title "{Exercise improves learning and memory impairments in sleep deprived female rats}" should be "Exercise improves learning and memory impairments in sleep deprived female rats"
# CechEtal14: 	title "{Caffeine suppresses exercise-enhanced long-term and location memory in middle-aged rats: Involvement of hippocampal Akt and CREB signaling}" should be "Caffeine suppresses exercise-enhanced long-term and location memory in middle-aged rats: involvement of hippocampal akt and creb signaling"
# CianEtal01: 	title "{Effects of fluid ingestion on cognitive function after heat stress or exercise-induced dehydration}" should be "Effects of fluid ingestion on cognitive function after heat stress or exercise-induced dehydration"
# CianEtal00: 	title "{Influence of variations in body hydration on cogntivie function}" should be "Influence of variations in body hydration on cogntivie function"
# CahiAlki03: 	title "{Epinephrine enhancement of human memory consolidation: Interaction with arousal at encoding}" should be "Epinephrine enhancement of human memory consolidation: interaction with arousal at encoding"
# McNeRadv15: 	title "{Mind racing: The influence of exercise on long-term memory consolidation}" should be "Mind racing: the influence of exercise on long-term memory consolidation"
# ColeTomp08: 	title "{Effects of acute exercise on executive processing, short-term and long-term memory}" should be "Effects of acute exercise on executive processing, short-term and long-term memory"
# AlomEtal13: 	title "{Forced and voluntary exercises equally improve spatial learning and memory and hippocampal BDNF levels}" should be "Forced and voluntary exercises equally improve spatial learning and memory and hippocampal {BDNF} levels"
# Arch11a: 	title "{Physical exercise alleviates debilities of normal aging and Alzheimer's disease}" should be "Physical exercise alleviates debilities of normal aging and {Alzheimer's} disease"
# ArchEtal15: 	title "{Effects of Physical Exercise on Depressive Symptoms and Biomarkers in Depression}" should be "Effects of physical exercise on depressive symptoms and biomarkers in depression"
# ArchKost12: 	title "{Physical exercise alleviates ADHD Symptoms: Regional deficits and development trajectory}" should be "Physical exercise alleviates {ADHD} symptoms: regional deficits and development trajectory"
# BabaEtal14: 	title "{Long term habitual exercise is associated with lower resting level of serum BDNF}" should be "Long term habitual exercise is associated with lower resting level of serum {BDNF}"
# BercEtal10: 	title "{Exercise and time-dependent benefits to learning and memory}" should be "Exercise and time-dependent benefits to learning and memory"
# ChadEtal10: 	title "{A neuroimaging investigation of the association between aerobic fitness, hippocampal volume, and memory performance in preadolescent children}" should be "A neuroimaging investigation of the association between aerobic fitness, hippocampal volume, and memory performance in preadolescent children"
# ChadEtal11b: 	title "{Aerobic fitness and executive control of relational memory in preadolescent children}" should be "Aerobic fitness and executive control of relational memory in preadolescent children"
# ChadEtal11a: 	title "{A Review of the Relation of Aerobic Fitness and Physical Activity to Brain Structure and Function in Children}" should be "A review of the relation of aerobic fitness and physical activity to brain structure and function in children"
# CotmBerc07: 	title "{Physical activity and the maintenance of cognition: Learning from animal models}" should be "Physical activity and the maintenance of cognition: learning from animal models"
# CotmEtal07: 	title "{Exercise builds brain health: key roles of growth factor cascades and inflammation}" should be "Exercise builds brain health: key roles of growth factor cascades and inflammation"
# CovaEtal07: 	title "{Effects of a maximal exercise test on neurocognitive function: Commentary}" should be "Effects of a maximal exercise test on neurocognitive function: commentary"
# CummEtal12: 	title "{The effect of physical activity on cognitive function after stroke: a systematic review}" should be "The effect of physical activity on cognitive function after stroke: a systematic review"
# CurrEtal09: 	title "{Cardio-respiratory fitness, habitual physical activity and serum brain derived neurotrophic factor (BDNF) in men and women}" should be "Cardio-respiratory fitness, habitual physical activity and serum brain derived neurotrophic factor {(BDNF}) in men and women"
# DingEtal06: 	title "{Insulin-like growth factor I interfaces with brain-derived neurotrophic factor-mediated synaptic plasticity to modulate aspects of exercise-induced cognitive function}" should be "Insulin-like growth factor {I} interfaces with brain-derived neurotrophic factor-mediated synaptic plasticity to modulate aspects of exercise-induced cognitive function"
# DinoEtal16: 	title "{The Effect of exercise training on resting concentrations of peripheral brain-derived neurotrophic factor (BDNF): A meta-analysis}" should be "The effect of exercise training on resting concentrations of peripheral brain-derived neurotrophic factor {(BDNF}): A meta-analysis"
# EganEtal03: 	title "{The BDNF val66met polymorphism affects activity-dependent secretion of BDNF and human memory and hippocampal function}" should be "The {BDNF} val66met polymorphism affects activity-dependent secretion of {BDNF} and human memory and hippocampal function"
# EggeEtal07: 	title "{Excercise, cognition, and Alzheimer's disease: More is not necessarily better}" should be "Excercise, cognition, and {Alzheimer's} disease: more is not necessarily better"
# EricEtal11: 	title "{Exercise training increases size of hippocampus and improves memory}" should be "Exercise training increases size of hippocampus and improves memory"
# EricEtal13: 	title "{The Brain-Derived Neurotrophic Factor Val66Met Polymorphism Moderates an Effect of Physical Activity on Working Memory Performance}" should be "The brain-derived neurotrophic factor val66met polymorphism moderates an effect of physical activity on working memory performance"
# EricEtal09: 	title "{Aerobic fitness is associated with hippocampal volume in elderly humans}" should be "Aerobic fitness is associated with hippocampal volume in elderly humans"
# FirtEtal17: 	title "{Aerobic exercise improves cognitive functioning in people with schizophrenia: A systematic review and meta-analysis}" should be "Aerobic exercise improves cognitive functioning in people with schizophrenia: A systematic review and meta-analysis"
# FloeEtal10: 	title "{Physical activity and memory functions: Are neurotrophins and cerebral gray matter volume the missing link?}" should be "Physical activity and memory functions: are neurotrophins and cerebral gray matter volume the missing link?"
# GapiEtal11: 	title "{The effects of physical activity on attention deficit hyperactivity disorder symptoms: The evidence}" should be "The effects of physical activity on attention deficit hyperactivity disorder symptoms: the evidence"
# GrifEtal11: 	title "{Aerobic exercise improves hippocampal function and increases BDNF in the serum of young adult males}" should be "Aerobic exercise improves hippocampal function and increases {BDNF} in the serum of young adult males"
# HariEtal03: 	title "{Brain-derived neurotrophic factor val66met polymorphism affects human memory-related hippocampal activity and predicts memory performance}" should be "Brain-derived neurotrophic factor val66met polymorphism affects human memory-related hippocampal activity and predicts memory performance"
# HayeEtal14: 	title "{Cardiorespiratory Fitness Is Associated With Cognitive Performance in Older But Not Younger Adults}" should be "Cardiorespiratory fitness is associated with cognitive performance in older but not younger adults"
# ...
# autocorrecting JoneWils05b[title] to "{T}heta rhythms coordinate hippocampal-prefrontal interactions in a spatial memory task"
# autocorrecting KlimEtal01b[title] to "Theta synchronization during episodic retrieval: {N}eural correlates of conscious awareness"
# autocorrecting WeisEtal00[title] to "Theta synchronization predicts efficient memory encoding of concrete and abstract nouns"
# autocorrecting CacuEtal04[title] to "Theta-modulated place-by-direction cells in the hippocampal formation of the rat"
# autocorrecting VertEtal01[title] to "Theta-rhythmically firing neurons in the anterior thalamus: implications for mnemonic functions of papez's circuit"
# autocorrecting HulmEtal99[title] to "Think before you speak: pauses, memory search, and trace redintegration processes in verbal memory span"
# autocorrecting GenoEtal02[title] to "Thresholding of statistical maps in functional neuroimaging using the false discovery rate"
# autocorrecting Kopp78[title] to "Time changes in the strengths of {A-B, A-C} lists; spontaneous recovery?"
# autocorrecting KoleOstr74[title] to "Time course of loss of information regarding pattern analyzing operations"
# autocorrecting MoreWard10[title] to "Time scale similarity and long-term memory for autobiographical events"
# autocorrecting SuttBart90[title] to "Time-derivative models of pavolovian reinforcement"
# autocorrecting BuscEtal06[title] to "Time-frequency analysis of target detection reveals an early interface between bottom-up and top-down processes in the gamma-band"
# autocorrecting LewaEtal06[title] to "Timeless memory: evidence against temporal distinctiveness models of short-term memory for serial order"
# autocorrecting RiouFlan92[title] to "Time-scale energy distributions: A general class extending wavelet transforms"
# autocorrecting LiuEtal09[title] to "Timing, timing, timing: fast decoding of object information from intracranial field potentials in human visual cortex"
# autocorrecting Murd93[title] to "{TODAM2}: A model for the storage and retrieval of item, associative, and serial-order information"
# autocorrecting DebeEtal03[title] to "Top-down attentional processing enhances auditory evoked gamma band activity"
# autocorrecting BuscMill07[title] to "Top-down versus bottom-up control of attention in the prefrontal and posterior parietal cortices"
# autocorrecting LismEtal01[title] to "Toward a physiologic explanation of behavioral data on human memory"
# autocorrecting FengEtal07[title] to "Toward closed-loop optimization of deep brain stimulation for {Parkinson's} disease: concepts and lessons from a computational model"
# autocorrecting BuchEtal95[title] to "Toward unbiased measurement of conscious and unconscious memory processes within the process dissociation framework"
# autocorrecting BallEtal04[title] to "Towards an implantable brain-machine interface based on epicortical field potentials"
# autocorrecting RamsEtal06[title] to "Towards human {BCI} applications based on cognitive brain systems: an investigation of neural signals recorded from the dorsolateral prefrontal cortex"
# autocorrecting TsaoEtal13[title] to "Traces of experience in the lateral entorhinal cortex"
# autocorrecting PolyEtal07[title] to "Tracking category-related neural patterns during free recall using scalp {EEG}"
# autocorrecting MortEtal07[title] to "Tracking encoding task context during free recall using scalp {EEG}"
# autocorrecting SedeNorm07[title] to "Tracking episodic and semantic retrieval with {fMRI} pattern classification"
# autocorrecting Nitz06[title] to "{T}racking route progression in the posterior parietal cortex"
# autocorrecting MazoLaur05[title] to "{T}ransient dynamics versus fixed points in odor representations by locust antennal lobe projection neurons"
# autocorrecting YushEtal10[title] to "Nearly automatic segmentation of hippocampal subfields in< i> in vivo</i> focal {T2-weighted} {MRI}"
# autocorrecting YuvaEtal08[title] to "Transient induced gamma-band response in {EEG} as a manifestation of miniature saccades"
# autocorrecting MeltEtal09[title] to "Transverse patterning dissociates human {EEG} theta power and hippocampal {BOLD} activation"
# autocorrecting LewaEtal09[title] to "Traveling economically through memory space: characterizing output order in memory for serial order"
# autocorrecting ErmeKlei01[title] to "Traveling electrical waves in cortex insights from phase dynamics and speculation on a computational role"
# autocorrecting KracEtal98[title] to "Treatment of tremor in {Parkinson}'s disease by subthalamic nucleus stimulation"
# autocorrecting FabiEtal00[title] to "{T}rue but not false memories produce a sensory signature in human lateralized brain potentials"
# autocorrecting Free92[title] to "Tutorial on neurobiology: from single neurons to brain chaos"
# autocorrecting EpstEtal08[title] to "Two kinds of {fMRI} repetition suppression? Evidence for dissociable neural mechanisms"
# autocorrecting Ster67b[title] to "Two operation in character-recognition:some evidence from reaction time measurements"
# autocorrecting KramEtal75[title] to "Two types of hippocampal rhythmical slow activity in both the rabbit and the rat: relations to behavior and effects of atropine, diethyl ether, urethane, and pentobarbital"
# autocorrecting BlooWatk99[title] to "Two-component theory of the suffix effect: contrary findings"
# autocorrecting SchaEtal08b[title] to "Two-dimensional movement control using electrocorticographic signals in humans"
# autocorrecting Chun97[title] to "Types and tokens in visual processing: A double dissociation between the attentional blink and repetition blindness"
# autocorrecting Berg29[title] to "{\"U}ber das {E}lektrenkephalogramm des menschen ({O}n the human electroencephalogram)"
# autocorrecting Rans02[title] to "Uber hemmung gleichzeitiger reizwirkungen"
# autocorrecting BittEtal08[title] to "Ultra-fine frequency tuning revealed in single neurons of human auditory cortex"
# autocorrecting CeraHend65[title] to "Unavailability and associative loss in {RI} and {PI}"
# autocorrecting HensEtal96[title] to "Unchained memory: error patterns rule out chaining models of immediate serial recall"
# autocorrecting HealEtal12b[title] to "Understanding age related memory impairments: new data and a model-based approach to theory development"
# autocorrecting UnswEtal10[title] to "Understanding the dynamics of correct and error responses in free recall: evidence from externalized free recall"
# autocorrecting MazzEtal10[title] to "Understanding the relationships between spike rate and delta/gamma frequency bands of {LFPs} and {EEGs} using a local cortical network model"
# autocorrecting EchaEtal00[title] to "Unified probabilistic framework for predicting and detecting seizure onsets in the brain and multitherapeutic device"
# autocorrecting SpieEtal01b[title] to "Unilateral temporal lobectomy patients show lateralized topographical and episodic memory deficits in a virtual town"
# autocorrecting SeliKaha09[title] to "Unpacking intuition: A conjecture"
# autocorrecting JacoSche03[title] to "Unpacking the cognitive map: the parallel map theory of hippocampal function"
# autocorrecting BeauEtal04[title] to "Unraveling multisensory integration: patchy organization within human {STS} multisensory cortex"
# autocorrecting QuirEtal04[title] to "Unsupervised spike detection and sorting with wavelets and superparamagnetic clustering"
# autocorrecting DiCaCox07[title] to "Untangling invariant object recognition"
# autocorrecting PlenKita98[title] to "Up and down states in striatal medium spiny neurons simultaneously recorded with spontaneous activity in fast-spiking interneurons studied in cortex-striatum-substantia nigra organotypic cultures"
# autocorrecting DunlHert00[title] to "Updating knowledge about encoding strategies: A componential analysis of learning about strategy effectiveness from task experience"
# autocorrecting CoopKnut08[title] to "Valence and salience contribute to nucleus accumbens activation"
# autocorrecting KatzEtal83[title] to "Validation of a short orientation-memory-concentration test of cognitive impairment"
# autocorrecting ConnEtal11[title] to "Variability of the relationship between electrophysiology and {BOLD-fMRI} across cortical regions in humans"
# autocorrecting KessEtal01[title] to "Varieties of human spatial memory: a meta-analysis on the effects of hippocampal lesions"
# autocorrecting KomoEtal13[title] to "Ventral hippocampal neurons are shaped by experience to represent behaviorally relevant contexts"
# autocorrecting DaviEtal05[title] to "Ventral striatum/nucleus accumbens activation to smoking-related pictorial cues in smokers and nonsmokers: a functional magnetic resonance imaging study"
# autocorrecting HealMcNa96[title] to "Verbal learning and memory : does the modal model still work?"
# autocorrecting Mart71[title] to "Verbal learning theory and independent retrieval phenomena"
# autocorrecting OjemDodr85[title] to "Verbal memory deficits after left temporal lobectomy for epilepsy"
# autocorrecting KramEtal88[title] to "Verbal memory errors in {Huntington's} and {A}lzheimer's dementias"
# autocorrecting CowaEtal94[title] to "Verbal memory span in children: speech timing clues to the mechanisms underlying age and word length effects"
# autocorrecting PourEtal05[title] to "View-independent coding of face identity in frontal and temporal cortices is modulated by familiarity: an event-related {fMRI} study"
# autocorrecting NeweEtal01[title] to "Viewpoint dependence in visual and haptic object recognition"
# autocorrecting RollOMar95[title] to "View-responsive neurons in the primate hippocampal complex"
# autocorrecting WitmEtal96[title] to "Virtual spaces and real world places: transfer of route knowledge"
# autocorrecting WhitEtal96[title] to "Virtual spaces and real-world places: transfer of route knowledge"
# autocorrecting RendCrai00[title] to "Virtual week and actual week: age-related differences in prospective memory"
# autocorrecting Sinn84[title] to "Virtues of the {Haversine}"
# autocorrecting Marr82[title] to "Vision: A computational investigation into the human representation and processing of visual information"
# autocorrecting HikoWurt83[title] to "Visual and oculomotor functions of monkey substantia nigra pars reticulata. {I}. relation of visual and auditory responses to saccades"
# autocorrecting KanwWojc00[title] to "Visual attention: insights from brain imaging"
# autocorrecting Fant64[title] to "Visual experience in infants: decreased attention familar patterns relative to novel ones"
# autocorrecting SingGray95[title] to "{V}isual feature integration and the temporal correlation hypothesis"
# autocorrecting VidaEtal06[title] to "Visual grouping and the focusing of attention induce gamma-band oscillations at different frequencies in human magnetoencephalogram signals"
# autocorrecting LogoShei96[title] to "Visual object recognition"
# autocorrecting Grah89[title] to "Visual pattern analyzers"
# autocorrecting GrosEtal72[title] to "Visual properties of neurons in inferotemporal cortex of the macaque"
# autocorrecting WilsEtal83[title] to "Visual receptive fields and response properties of neurons in human temporal lobe and visual pathways"
# autocorrecting Wolf98[title] to "Visual search"
# autocorrecting LopeKodi07[title] to "Visual servoing for nonholonomically constrained three degree of freedom kinematic systems"
# autocorrecting GraiEtal02[title] to "Visualization of significant erd/ers patterns in multichannel {EEG} and {ECoG} data"
# autocorrecting GrubOtte10[title] to "Voluntary control over prestimulus activity related to encoding"
# autocorrecting Thun51[title] to "Warm-up effect as a function of level of practice in verbal learning"
# autocorrecting JerbEtal09c[title] to "Watching brain {TV} and playing brain ball: exploring novel {BCI} strategies using real-time analysis of human intracranial data"
# autocorrecting BerrSwai89[title] to "Water deprivation optimizes hippocampal activity and facilitates nictitating membrane conditioning"
# autocorrecting SchnEtal06[title] to "Weak pairwise correlations imply strongly correlated network states in a neural population"
# autocorrecting Wech08[title] to "{Wechsler} adult intelligence scale"
# autocorrecting Wech97[title] to "{Wechsler} adult intelligence {Scale-III} {(WAIS-III})"
# autocorrecting Wech81[title] to "{Wechsler} adult intelligence scale--- revised"
# autocorrecting Wech45[title] to "{Wechsler} memory scale"
# autocorrecting HeegRess02[title] to "What does {fMRI} tell us about neuronal activity?"
# autocorrecting KensEtal03[title] to "What neural correlates underlie successful encoding and retrieval? A functional magnetic resonance imaging study using a divided attention paradigm"
# autocorrecting PittMyun02[title] to "When a good fit can be bad"
# autocorrecting DavaEtal01[title] to "When keeping in mind supports later bringing to mind: neural markers of phonological rehearsal predict subsequent remembering"
# autocorrecting DaseEtal04[title] to "When less means more: deactivations during encoding that predict subsequent memory"
# autocorrecting KensScha99[title] to "When true memories suppress false memories: effects of ageing"
# autocorrecting EpstEtal07[title] to "Where am {I} now? Distinct roles for parahippocampal and retrosplenial cortices in place recognition"
# autocorrecting LaufEtal06[title] to "Where the {BOLD} signal goes when alpha {EEG} leaves"
# autocorrecting BrowEtal10[title] to "Which way was {I} going? Contextual retrieval supports the disambiguation of well learned overlapping navigational routes"
# autocorrecting LeaEtal07[title] to "Who do you look like? Evidence for facial stereotypes for male names"
# autocorrecting WataEtal12[title] to "Whole-brain mapping of direct inputs to midbrain dopamine neurons"
# autocorrecting BailEtal08[title] to "Why does working memory span predict complex cognition? Testing the strategy affordance hypothesis"
# autocorrecting Gige08[title] to "Why heuristics work"
# autocorrecting BaltStau00[title] to "Wisdom: A metaheuristic (pragmatic) to orchestrate mind and virtue toward excellence"
# autocorrecting ArndRede02[title] to "Word frequency and receiver operating characteristic curves in recognition memory: evidence for a dual-process interpretation"
# autocorrecting Clar92[title] to "Word frequency effects in associative and item recognition"
# autocorrecting MacLKamp96[title] to "Word frequency effects on recall, recognition, and word fragment completion tests"
# autocorrecting Greg76[title] to "Word frequency, recognition and recall"
# autocorrecting BaloSpie99[title] to "Word frequency, repetition, and lexicality effects in word recognition tasks: beyond measures of central tendency"
# autocorrecting MartFedi83[title] to "Word production and comprehension in {Alzheimer's} disease: the breakdown of semantic knowledge"
# autocorrecting NobrEtal94[title] to "Word recognition in the human inferior temporal lobe"
# autocorrecting HulmEtal97[title] to "Word-frequency effects on short-term memory tasks: evidence for a redintegration process in immediate serial recall"
# autocorrecting NairNeat95[title] to "Word-length effect in immediate memory: overwriting trace decay theory"
# autocorrecting Mill95[title] to "{WordNet}: a lexical database for {English}"
# autocorrecting Badd86[title] to "Working memory"
# autocorrecting AckeEtal05[title] to "Working memory and intelligence: the same or different constructs?"
# autocorrecting UnswEtal13b[title] to "Working memory capacity and retrieval from long-term memory: the role of controlled search"
# autocorrecting UnswSpil10[title] to "Working memory capacity: attention control, secondary memory, or both? A direct test of the dual-component model"
# autocorrecting PellMoor00[title] to "X-means: extending k-means with efficient estimation of the number of clusters"
# autocorrecting OCraEtal99[title] to "{fMRI} evidence for objects as the units of attentional selection"
# autocorrecting HestEtal05[publisher] to "{W}. {H}. Freeman"

# %%
errors2, corrected_bib2 = check_bib('cleaned.bib', autofix=True, outfile='double_cleaned.bib')
# Out:
# loading cleaned.bib...done
# Checking for duplicated keys and entries...
# No keys with multiple entries were found.
# 0it [00:00, ?it/s]
# No entries with duplicated authors/titles were found.
#
#
# running check: ID...
# 5744it [00:00, 117390.65it/s]
# no IDs to fix!
# 5744it [00:00, 130002.60it/s]
# 5744it [00:00, 120657.69it/s]
# running check: ID...
# no IDs to fix!
#
#
# No ambiguous page numbers were found.
#
#
# running check: pages...
# no pagess to fix!
# 5744it [00:00, 128202.56it/s]
# running check: journal...
# no journals to fix!
# 5744it [00:00, 117758.44it/s]
# running check: booktitle...
# no booktitles to fix!
# 5744it [00:00, 122737.19it/s]
# running check: title...
# no titles to fix!
# 5744it [00:00, 122979.65it/s]
# 0it [00:00, ?it/s]
# running check: publisher...
# no publishers to fix!
#
#
# running check: author...
# 5744it [00:00, 125781.60it/s]
# 5744it [00:00, 122129.93it/s]
# no authors to fix!
#
#
# running check: editor...
# no editors to fix!
# 5744it [00:00, 129720.51it/s]
# 100%|██████████| 5744/5744 [00:00<00:00, 89307.66it/s]
# 0it [00:00, ?it/s]
# running check: address...
# no addresss to fix!
#
#
# searching for extra fields...
#
# autocorrecting...

# %%
compare_bibs('../cdl.bib', 'github')
# Out:
# loading ../cdl.bib...done
# loading https://raw.githubusercontent.com/ContextLab/CDL-bibliography/master/cdl.bib...
# 100%|██████████| 5741/5741 [00:00<00:00, 62390.85it/s]
# done
# removed the following entries: VanOEtal03, FranEtal06, Schw78
#
# added the following entries: FranEtal06a, Tulv02c, FranEtal06b, Schw78b, AnasEtal17, Schw78a, VanOEtal03b, DonaRugg97, MillEtal71, VanOEtal03a, Jaco92
#
# modified the following entries: SchaEtal08a, FranEtal07a, MollEtal06, ShirEtal10, Skan98, ZaghEtal03, HealEtal14b, ShifStey97, HariEtal13, PastEtal08a, DesaEtal12, FrenDoub74, WatsPell83, Rest57, Forg95, CoxSavo03, KrieEtal08b, BaunEtal01, HuxtEtal08, HansStau13, CieuEtal58, VansEtal10, AlvaEtal94, SehaEtal08, BevaEtal02, AbelEtal05, BellEtal12, TalaHirs05, Semo23, Keck07, Wick68, CovaEtal07, Wech81, HernEtal00, HeatEtal93, EichEtal92, RoseEtal10, BromEtal10b, JoelEtal02, AfshEtal13, BrazEtal02, FellEtal06b, Dobk07, SterEtal96b, DuchNeel89, SurpEtal06, BurrOkad75, DaviInde07, WichMart71, MormEtal05, ChosNaga01, EngeFrie10, TortEtal09, FiscMode03, AndeEtal04a, Gomu53, Ober28, VoytEtal10a, WageEtal05, SnodCorw88, McKoRatc89, RizzKaha00, ElliAshb89, SpilUnsw11, WarrEtal10, FletEtal95, RosbEtal09, CoopEtal03, UnswEtal09, Ekst04, CalvEtal73, BancEtal94, Tulv02a, PlasEtal07, BannEtal04, KomoEtal09, TallEtal97, MillEtal07d, Hass05, HolrEtal06, BodiEtal05, Aust14, JensTesc00, DonaRugg98, ShinEtal99, HealKaha14b, JensEtal02, HowaEtal09, Hint04, Raai03, MacWEtal01, JacoEtal10b, Fust01, StroEtal15, OnslEtal11, WangEtal13, RayEtal08c, RayEtal08b, LeutEtal04b, WaltEtal08, LincNati81, EngeEtal05, LofbEtal13, BlanEtal08a, CoheEtal09b, GlucEtal02, BuzsEtal12, Nico03, Nied91, PfurEtal96, UsheEtal08, MurEtal12, BragEtal95, ZhanEtal06, JahaEtal13, PhamEtal05, RosaEtal07, AschLind63, LebeNico06, JerbEtal09c
# False

# %%
compare_bibs('../cdl.bib', 'cleaned.bib')
# Out:
# loading ../cdl.bib...done
# loading cleaned.bib...
# 100%|██████████| 5742/5742 [00:00<00:00, 59505.29it/s]
# done
# removed the following entries: FranEtal06, FranEtal06c
#
# added the following entries: FranEtal06a, FranEtal06b
#
# modified the following entries: GreeRany57, Wils88, SolsEtal08, EkstEtal05, StonNysw27, ShirEtal10, ZaghEtal03, HommSalt96, AngeEtal10, KlimEtal01b, DavaEtal01, HealEtal14b, SaadEtal14a, deCa05a, EpstWard10, CotmEtal07, BlaxNeel83, WaltEtal07, BuscEtal99, Redi04, CheuChan03, KensEtal03, AddaEtal11, TsenEtal01, SmitRatc04, BirnEtal04, BabiEtal08, Bara09, KramEtal75, VansEtal10, BabaEtal14, Brow76, JacoEtal05d, ArchKost12, DaPo67, Levy96, BrowEtal01, SchlEtal07, Capl05, CoheEtal00, CartvanV07, MaguEtal98b, ReinEtal92, Murd93, RangEtal04a, BernHend01, NoldEtal98, Wech81, HowaKaha02a, CabeStJa07, WilsEtal84, Vand00, KeilEtal99, Wass04, KeppUnde67, HeckEtal98, VanSEtal07, CzurEtal99, Hass08, Fodo83, NateEtal06, KeriEtal07, FellEtal08, FroeDuff02, SiegEtal09, Post72, ShimSqui84, SawaEtal06, Hint03, Buzs04, GaroEtal05, GammEtal04, HartEtal03, EngeFrie10, MazzEtal10, AverEtal06, HealMcNa96, Gomu53, NaveEtal07, BabiEtal10, LopevanL77, EpstEtal08, StefEtal05, BohbEtal98, FarrLewa04, RizzKaha00, BodiEtal01, Murd72, Gige08, AvidEtal02, GrahEtal99, GlanAdam85, MacDEtal04, YonePark07, Hass12, McCrGrac07, SnowEtal16, KellEtal03, CusaEtal09, KutaHill80, IariEtal08, MaroEtal12, MotlPilu12, GoldPape12, RougORei02, NormWick69, DoshEtal89, HintEtal73, SchuReyn13, FooEtal05, HerrEtal09, SeguEtal96, DobbEtal02, GrayEtal89, MoriEtal08, Hock08, PineEtal02, McNaEtal92b, Penf75, KarpRoed08, BungEtal04, GrubGosc04, RuscEtal11, WintEtal07, Bird80, FreuEtal09, RissGlan87, Arch11a, PhilEtal98, TanWard00, Morr01, PansKori03, HalpEtal16, JoneMewh07, ChenEtal15, WatkTodr80, SegaEtal12, Mill89, ThomEtal97, DaleEtal99, SinhEtal06, McClEtal86, SaltEtal99, WebeMurd89, DuchEtal98, MotlEtal11, Fust09, MehtEtal02, ChamEtal03, TulvRose06, vanZEtal12, Voro08, CianEtal01, BeukEtal19, AronPold06, MurEtal12, NowaBull97, MerrEtal06, MillEtal96, Chos05, DesmFiez98, MurdLamo88, SuttBart90, MullEtal05, JerbEtal09c, Nitz06, McCaEtal95, BestEtal01, BattBell79, SquiZola91, KnieEtal06, Murd99, LarsSmit12, OverBeck09, NessMeck03, MillEtal12b, DireRobe06, Baas05, GlanAdam90, deGaEtal12, HernEtal97, WhitEtal96, KuhlEtal12a, Brod99, GrubEtal06, Raai93, DelaEtal12, MummEtal00, PedrEtal11, FellEtal06a, JaspPenf49, ODohEtal04, SporZwi04, vonSSarn00, RossLand78, SalaEtal05, PeteEtal62b, UnswBrew09, BrowChat95, HillMunt84, KaisLutz05, NestCarl06, Ryan69, RendCrai00, Post78, MacLKamp96, TunEtal98, GrabLism03, BichEtal05, BradEtal92, Verh03, TideTull76, KossEtal02, LeunEtal07, McGe42, BurtEtal08, Koun94, EricEtal09, HulmEtal03, MontEtal89, MellEtal07, MainEtal08, FellEtal06b, CeciTabo81, YounEtal97, KahnWrig71, JoneJaco01, WichMart71, BaldEtal02, OjemEtal89, Bart04, CoheEtal07, YoneEtal99, Ober28, JacoEtal05a, GabrEtal98, Mons03, FabiEtal00, OnypEtal10, ParkYone07, AlleEtal12a, EckhEtal88, Bron95, TangEtal08, KandEtal00, SahiEtal09, KahaJaco00, LewaFarr00, NormEtal06b, Lism97, CowaEtal02, LeviEtal02, NormORei03, StorEtal11, KahaEtal05b, Marm83, CacuEtal04, MacDEtal11, Stra70, JoneWils05b, HoffMcNa02, YotsEtal07, GraySing89, Arch11b, MoscEtal05, TeppBola04, BuckEtal04, Free75, MacWEtal01, Hebb49, HeslEtal05, Cast05, LiLewa93, GardEtal06, MartEtal96, BrauEtal01, Vapn95, NichHolm01, DhamEtal08, KensScha99, SanbGrif08, GaoEtal15, GoloStar04, HokEtal07, HamiEtal09, LeveEtal09, NewsKemp06, AlbeChib93, DoshRose97, DamiEtal99a, CantEtal03, HillEtal87, Murd74, WyleEtal82, BattEtal04, EwbaEtal12, Luke17, Give96, Adey67b, SummMang05a, LogoEtal07, MouEtal07, SedeNorm07, GravEtal85, Ansc73, HeitEtal90, HassEich05, DestEtal99, McInCrai87, WattPate99, Free00, EckhEtal04, Thie03, NelsEtal97, PfurLope99, Este94, LadoEtal02, HowaKaha00, DesaEtal12, ElgeEtal04, Huth13, Bjor70, MainEtal07, FujiMats89, WatsPell83, MoorArms03, Hash73, UlbeEtal01b, WoerEtal03, Rans02, KochEtal09, BurgEtal07, RealEtal07, PuceEtal99, Este59, MormEtal08a, FranEtal04b, KaneEtal04, VossPall08, OjemDodr85, BattMont69, MitrPesa99, MeltIrwi40, Shif75, ShutEtal83, BronEtal09, WillEtal71, OCraEtal99, TortEtal08, RoseRosn91, WilsEtal80, Gr ...
# False

# %%
compare_bibs('cleaned.bib', 'double_cleaned.bib')
# Out:
# loading cleaned.bib...done
# loading double_cleaned.bib...

# %% [markdown]
# To do:
# - ~~handle first-author surnames that start with lowercase characters~~
# - ~~better handling of curly braces to preserve name ordering~~
# - ~~better handling of escape characters~~
# - ~~ensure bibtex file compiles and gets parsed correctly~~
# - ~~Check duplicate titles/authors (fail if detected)~~
# - ~~Check bibtex keys.  Duplicates should be assigned a suffix of 'a', 'b', etc.~~
# - ~~If keys match aside from suffix then still allow the bibtex file to "pass" as long as all "matching" keys are unique *and* all have suffixes *and* the suffixes span a, b, c, ..., etc. without gaps~~
# ~~- Correct page numberings:~~
#   ~~- Change hyphens to n-dashes~~~~
#   ~~- Change m-dashes to n-dashes~~
#   ~~- Remove spaces in page ranges~~
#   ~~- Print a warning for strangely formatted pages: leading 0, non-digits, very large numbers (greater than 10K?) but allow bibtex file to pass~~
# - ~~remove everything except for "keep_fields"~~
#   - ~~Also add a "force" field that, when present, causes the checker to automatically pass that entry (if set to True); this will be used as a workaround for special cases not handled by the parser/checker~~
# - ~~change all urls, dois, and page numbers to lowercase~~
#
# Clean up:
# - ~~correct all "strings" to full journal names~~
# - ~~correct capitalization of journal names~~
# - ~~correct all journal abbreviations to full journal names~~
# - ~~Ensure no periods in journal names~~
# - ~~Ensure no periods at the ends of affiliations or titles~~
# - ~~Check for compressed initials (AA --> A A; A.A. --> A A; etc.)~~
#
# Bonus:
# - Use scholarly to verify information.  However, this is currently unreliable (server seems to hang frequently) and too slow to be viable
